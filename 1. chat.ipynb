# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(model="llama3.2:1b")

result = llm.invoke("What is the capital of Italy?")

print(result.content)
# Out:
# The capital of Italy is Rome (Roma in Italian).

# %%
# !uv add langchain-openai
# Out:
# Resolved 68 packages in 508ms
# ⠙ Preparing packages... (0/7)
# ⠙ Preparing packages... (0/7)--------------     0 B/19.80 KiB
# ⠙ Preparing packages... (0/7)--------------     0 B/19.80 KiB
# distro               ------------------------------     0 B/19.80 KiB
# ⠙ Preparing packages... (0/7)--------------     0 B/279.29 KiB
# distro               ------------------------------ 16.00 KiB/19.80 KiB
# ⠙ Preparing packages... (0/7)--------------     0 B/279.29 KiB
# distro               ------------------------------ 16.00 KiB/19.80 KiB
# ⠙ Preparing packages... (0/7)--------------     0 B/279.29 KiB
# distro               ------------------------------ 16.00 KiB/19.80 KiB
# ⠙ Preparing packages... (0/7)--------------     0 B/279.29 KiB
# distro               ------------------------------ 16.00 KiB/19.80 KiB
# tqdm                 ------------------------------     0 B/76.70 KiB
# ⠙ Preparing packages... (0/7)--------------     0 B/279.29 KiB
# distro               ------------------------------ 19.80 KiB/19.80 KiB
# tqdm                 ------------------------------     0 B/76.70 KiB
# ⠙ Preparing packages... (0/7)--------------     0 B/279.29 KiB
# distro               ------------------------------ 19.80 KiB/19.80 KiB
# tqdm                 ------------------------------ 14.88 KiB/76.70 KiB
# ⠙ Preparing packages... (0/7)--------------     0 B/279.29 KiB
# tqdm                 ------------------------------ 14.88 KiB/76.70 KiB
# ⠙ Preparing packages... (0/7)--------------     0 B/279.29 KiB
# tqdm                 ------------------------------ 30.88 KiB/76.70 KiB
# ⠙ Preparing packages... (0/7)--------------     0 B/279.29 KiB
# tqdm                 ------------------------------ 30.88 KiB/76.70 KiB
# ⠙ Preparing packages... (0/7)--------------     0 B/279.29 KiB
# tqdm                 ------------------------------ 30.88 KiB/76.70 KiB
# ⠙ Preparing packages... (0/7)--------------     0 B/279.29 KiB
# langchain-openai     ------------------------------     0 B/72.57 KiB
# tqdm                 ------------------------------ 30.88 KiB/76.70 KiB
# ⠙ Preparing packages... (0/7)--------------     0 B/279.29 KiB
# langchain-openai     ------------------------------     0 B/72.57 KiB
# tqdm                 ------------------------------ 30.88 KiB/76.70 KiB
# ⠙ Preparing packages... (0/7)--------------     0 B/279.29 KiB
# langchain-openai     ------------------------------     0 B/72.57 KiB
# tqdm                 ------------------------------ 30.88 KiB/76.70 KiB
# ⠙ Preparing packages... (0/7)--------------     0 B/279.29 KiB
# langchain-openai     ------------------------------     0 B/72.57 KiB
# tqdm                 ------------------------------ 30.88 KiB/76.70 KiB
# ⠙ Preparing packages... (0/7)--------------     0 B/279.29 KiB
# langchain-openai     ------------------------------     0 B/72.57 KiB
# tqdm                 ------------------------------ 30.88 KiB/76.70 KiB
# regex                ------------------------------     0 B/279.29 KiB
# ⠙ Preparing packages... (0/7)--------------     0 B/311.47 KiB
# langchain-openai     ------------------------------     0 B/72.57 KiB
# regex                ------------------------------     0 B/279.29 KiB
# jiter                ------------------------------     0 B/311.47 KiB
# openai               ------------------------------     0 B/767.82 KiB
# ⠙ Preparing packages... (0/7)--------------     0 B/973.71 KiB
# langchain-openai     ------------------------------ 72.57 KiB/72.57 KiB
# regex                ------------------------------ 119.80 KiB/279.29 KiB
# jiter                ------------------------------ 64.00 KiB/311.47 KiB
# openai               ------------------------------ 62.92 KiB/767.82 KiB
# ⠙ Preparing packages... (0/7)-------------- 78.92 KiB/973.71 KiB
# regex                ------------------------------ 119.80 KiB/279.29 KiB
# jiter                ------------------------------ 64.00 KiB/311.47 KiB
# openai               ------------------------------ 62.92 KiB/767.82 KiB
# ⠙ Preparing packages... (0/7)-------------- 78.92 KiB/973.71 KiB
# jiter                ------------------------------ 271.83 KiB/311.47 KiB
# openai               ------------------------------ 138.51 KiB/767.82 KiB
# ⠙ Preparing packages... (0/7)-------------- 270.92 KiB/973.71 KiB
# openai               ------------------------------ 158.92 KiB/767.82 KiB
# ⠙ Preparing packages... (0/7)-------------- 392.56 KiB/973.71 KiB
# ⠙ Preparing packages... (0/7)-------------- 302.92 KiB/767.82 KiB
# ⠙ Preparing packages... (0/7)-------------- 392.56 KiB/767.82 KiB
# Prepared 7 packages in 153ms
# Installed 7 packages in 11ms
#  + distro==1.9.0
#  + jiter==0.10.0
#  + langchain-openai==0.3.29
#  + openai==1.99.5
#  + regex==2025.7.34
#  + tiktoken==0.11.0
#  + tqdm==4.67.1

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-4o-mini")

result = llm.invoke("What is the capital of Italy?")

print(result.content)
# Out:
# The capital of Italy is Rome.

# %%
from langchain_openai import AzureOpenAI

llm = AzureOpenAI(model="gpt-4o-mini")

result = llm.invoke("What is the capital of Italy?")

print(result.content)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[20], line 5
#       1 from langchain_openai import AzureOpenAI
#       3 llm = AzureOpenAI(model="gpt-4o-mini")
# ----> 5 result = llm.invoke("What is the capital of Italy?")
#       7 print(result.content)
#
# File ~/Desktop/langchain-basics/.venv/lib/python3.13/site-packages/langchain_core/language_models/llms.py:389, in BaseLLM.invoke(self, input, config, stop, **kwargs)
#     378 @override
#     379 def invoke(
#     380     self,
#    (...)    385     **kwargs: Any,
#     386 ) -> str:
#     387     config = ensure_config(config)
#     388     return (
# --> 389         self.generate_prompt(
#     390             [self._convert_input(input)],
#     391             stop=stop,
#     392             callbacks=config.get("callbacks"),
#     393             tags=config.get("tags"),
#     394             metadata=config.get("metadata"),
#     395             run_name=config.get("run_name"),
#     396             run_id=config.pop("run_id", None),
#     397             **kwargs,
#     398         )
#     399         .generations[0][0]
#     400         .text
#     401     )
#
# File ~/Desktop/langchain-basics/.venv/lib/python3.13/site-packages/langchain_core/language_models/llms.py:766, in BaseLLM.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     757 @override
#     758 def generate_prompt(
#     759     self,
#    (...)    763     **kwargs: Any,
#     764 ) -> LLMResult:
#     765     prompt_strings = [p.to_string() for p in prompts]
# --> 766     return self.generate(prompt_strings, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/Desktop/langchain-basics/.venv/lib/python3.13/site-packages/langchain_core/language_models/llms.py:971, in BaseLLM.generate(self, prompts, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     956 if (self.cache is None and get_llm_cache() is None) or self.cache is False:
#     957     run_managers = [
#     958         callback_manager.on_llm_start(
#     959             self._serialized,
#    (...)    969         )
#     970     ]
# --> 971     return self._generate_helper(
#     972         prompts,
#     973         stop,
#     974         run_managers,
#     975         new_arg_supported=bool(new_arg_supported),
#     976         **kwargs,
#     977     )
#     978 if len(missing_prompts) > 0:
#     979     run_managers = [
#     980         callback_managers[idx].on_llm_start(
#     981             self._serialized,
#    (...)    988         for idx in missing_prompt_idxs
#     989     ]
#
# File ~/Desktop/langchain-basics/.venv/lib/python3.13/site-packages/langchain_core/language_models/llms.py:792, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     781 def _generate_helper(
#     782     self,
#     783     prompts: list[str],
#    (...)    788     **kwargs: Any,
#     789 ) -> LLMResult:
#     790     try:
#     791         output = (
# --> 792             self._generate(
#     793                 prompts,
#     794                 stop=stop,
#     795                 # TODO: support multiple run managers
#     796                 run_manager=run_managers[0] if run_managers else None,
#     797                 **kwargs,
#     798             )
#     799             if new_arg_supported
#     800             else self._generate(prompts, stop=stop)
#     801         )
#     802     except BaseException as e:
#     803         for run_manager in run_managers:
#
# File ~/Desktop/langchain-basics/.venv/lib/python3.13/site-packages/langchain_openai/llms/base.py:333, in BaseOpenAI._generate(self, prompts, stop, run_manager, **kwargs)
#     317     choices.append(
#     318         {
#     319             "text": generation.text,
#    (...)    330         }
#     331     )
#     332 else:
# --> 333     response = self.client.create(prompt=_prompts, **params)
#     334     if not isinstance(response, dict):
#     335         # V1 client returns the response in an PyDantic object instead of
#     336         # dict. For the transition period, we deep convert it to dict.
#     337         response = response.model_dump()
#
# File ~/Desktop/langchain-basics/.venv/lib/python3.13/site-packages/openai/_utils/_utils.py:287, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     285             msg = f"Missing required argument: {quote(missing[0])}"
#     286     raise TypeError(msg)
# --> 287 return func(*args, **kwargs)
#
# File ~/Desktop/langchain-basics/.venv/lib/python3.13/site-packages/openai/resources/completions.py:541, in Completions.create(self, model, prompt, best_of, echo, frequency_penalty, logit_bias, logprobs, max_tokens, n, presence_penalty, seed, stop, stream, stream_options, suffix, temperature, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     512 @required_args(["model", "prompt"], ["model", "prompt", "stream"])
#     513 def create(
#     514     self,
#    (...)    539     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     540 ) -> Completion | Stream[Completion]:
# --> 541     return self._post(
#     542         "/completions",
#     543         body=maybe_transform(
#     544             {
#     545                 "model": model,
#     546                 "prompt": prompt,
#     547                 "best_of": best_of,
#     548                 "echo": echo,
#     549                 "frequency_penalty": frequency_penalty,
#     550                 "logit_bias": logit_bias,
#     551                 "logprobs": logprobs,
#     552                 "max_tokens": max_tokens,
#     553                 "n": n,
#     554                 "presence_penalty": presence_penalty,
#     555                 "seed": seed,
#     556                 "stop": stop,
#     557                 "stream": stream,
#     558                 "stream_options": stream_options,
#     559                 "suffix": suffix,
#     560                 "temperature": temperature,
#     561                 "top_p": top_p,
#     562                 "user": user,
#     563             },
#     564             completion_create_params.CompletionCreateParamsStreaming
#     565             if stream
#     566             else completion_create_params.CompletionCreateParamsNonStreaming,
#     567         ),
#     568         options=make_request_options(
#     569             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     570         ),
#     571         cast_to=Completion,
#     572         stream=stream or False,
#     573         stream_cls=Stream[Completion],
#     574     )
#
# File ~/Desktop/langchain-basics/.venv/lib/python3.13/site-packages/openai/_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Desktop/langchain-basics/.venv/lib/python3.13/site-packages/openai/_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# NotFoundError: Error code: 404 - {'error': {'code': '404', 'message': 'Resource not found'}}

# %%
# !uv add langchain-anthropic
# Out:
# Resolved 71 packages in 155ms
# ⠙ Preparing packages... (0/2)
# ⠙ Preparing packages... (0/2)--------------     0 B/29.12 KiB
# ⠙ Preparing packages... (0/2)m------------- 16.00 KiB/29.12 KiB
# ⠙ Preparing packages... (0/2)m------------- 16.00 KiB/29.12 KiB
# langchain-anthropic  ------------------------------ 16.00 KiB/29.12 KiB
# ⠙ Preparing packages... (0/2)--------------     0 B/289.67 KiB
# langchain-anthropic  ------------------------------ 29.12 KiB/29.12 KiB
# ⠙ Preparing packages... (0/2)--------------     0 B/289.67 KiB
# ⠙ Preparing packages... (0/2)--------------     0 B/289.67 KiB
# ⠙ Preparing packages... (0/2)-------------- 14.92 KiB/289.67 KiB
# ⠙ Preparing packages... (0/2)-------------- 30.92 KiB/289.67 KiB
# ⠙ Preparing packages... (0/2)-------------- 46.92 KiB/289.67 KiB
# ⠙ Preparing packages... (0/2)-------------- 62.92 KiB/289.67 KiB
# ⠙ Preparing packages... (0/2)-------------- 78.92 KiB/289.67 KiB
# ⠙ Preparing packages... (0/2)-------------- 94.92 KiB/289.67 KiB
# ⠙ Preparing packages... (0/2)-------------- 110.92 KiB/289.67 KiB
# ⠙ Preparing packages... (0/2)-------------- 126.92 KiB/289.67 KiB
# ⠙ Preparing packages... (0/2)-------------- 142.92 KiB/289.67 KiB
# ⠙ Preparing packages... (0/2)m------------- 158.92 KiB/289.67 KiB
# ⠙ Preparing packages... (0/2)----------- 174.92 KiB/289.67 KiB
# ⠙ Preparing packages... (0/2)---------- 190.92 KiB/289.67 KiB
# Prepared 2 packages in 73ms
# Installed 2 packages in 5ms
#  + anthropic==0.62.0
#  + langchain-anthropic==0.3.18

# %%
from langchain_anthropic import ChatAnthropic

llm = ChatAnthropic(model="claude-3-5-sonnet-20240620")

result = llm.invoke("What is the capital of Italy?")

print(result.content)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 5
#       1 from langchain_anthropic import ChatAnthropic
#       3 llm = ChatAnthropic(model="claude-3-5-sonnet-20240620")
# ----> 5 result = llm.invoke("What is the capital of Italy?")
#       7 print(result.content)
#
# File ~/Desktop/langchain-basics/.venv/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:383, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     371 @override
#     372 def invoke(
#     373     self,
#    (...)    378     **kwargs: Any,
#     379 ) -> BaseMessage:
#     380     config = ensure_config(config)
#     381     return cast(
#     382         "ChatGeneration",
# --> 383         self.generate_prompt(
#     384             [self._convert_input(input)],
#     385             stop=stop,
#     386             callbacks=config.get("callbacks"),
#     387             tags=config.get("tags"),
#     388             metadata=config.get("metadata"),
#     389             run_name=config.get("run_name"),
#     390             run_id=config.pop("run_id", None),
#     391             **kwargs,
#     392         ).generations[0][0],
#     393     ).message
#
# File ~/Desktop/langchain-basics/.venv/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:1006, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     997 @override
#     998 def generate_prompt(
#     999     self,
#    (...)   1003     **kwargs: Any,
#    1004 ) -> LLMResult:
#    1005     prompt_messages = [p.to_messages() for p in prompts]
# -> 1006     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/Desktop/langchain-basics/.venv/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:825, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     822 for i, m in enumerate(input_messages):
#     823     try:
#     824         results.append(
# --> 825             self._generate_with_cache(
#     826                 m,
#     827                 stop=stop,
#     828                 run_manager=run_managers[i] if run_managers else None,
#     829                 **kwargs,
#     830             )
#     831         )
#     832     except BaseException as e:
#     833         if run_managers:
#
# File ~/Desktop/langchain-basics/.venv/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:1072, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1070     result = generate_from_stream(iter(chunks))
#    1071 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1072     result = self._generate(
#    1073         messages, stop=stop, run_manager=run_manager, **kwargs
#    1074     )
#    1075 else:
#    1076     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/Desktop/langchain-basics/.venv/lib/python3.13/site-packages/langchain_anthropic/chat_models.py:1498, in ChatAnthropic._generate(self, messages, stop, run_manager, **kwargs)
#    1496 payload = self._get_request_payload(messages, stop=stop, **kwargs)
#    1497 try:
# -> 1498     data = self._create(payload)
#    1499 except anthropic.BadRequestError as e:
#    1500     _handle_anthropic_bad_request(e)
#
# File ~/Desktop/langchain-basics/.venv/lib/python3.13/site-packages/langchain_anthropic/chat_models.py:1357, in ChatAnthropic._create(self, payload)
#    1355 if "betas" in payload:
#    1356     return self._client.beta.messages.create(**payload)
# -> 1357 return self._client.messages.create(**payload)
#
# File ~/Desktop/langchain-basics/.venv/lib/python3.13/site-packages/anthropic/_utils/_utils.py:283, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     281             msg = f"Missing required argument: {quote(missing[0])}"
#     282     raise TypeError(msg)
# --> 283 return func(*args, **kwargs)
#
# File ~/Desktop/langchain-basics/.venv/lib/python3.13/site-packages/anthropic/resources/messages/messages.py:997, in Messages.create(self, max_tokens, messages, model, metadata, service_tier, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#     990 if model in DEPRECATED_MODELS:
#     991     warnings.warn(
#     992         f"The model '{model}' is deprecated and will reach end-of-life on {DEPRECATED_MODELS[model]}.\nPlease migrate to a newer model. Visit https://docs.anthropic.com/en/docs/resources/model-deprecations for more information.",
#     993         DeprecationWarning,
#     994         stacklevel=3,
#     995     )
# --> 997 return self._post(
#     998     "/v1/messages",
#     999     body=maybe_transform(
#    1000         {
#    1001             "max_tokens": max_tokens,
#    1002             "messages": messages,
#    1003             "model": model,
#    1004             "metadata": metadata,
#    1005             "service_tier": service_tier,
#    1006             "stop_sequences": stop_sequences,
#    1007             "stream": stream,
#    1008             "system": system,
#    1009             "temperature": temperature,
#    1010             "thinking": thinking,
#    1011             "tool_choice": tool_choice,
#    1012             "tools": tools,
#    1013             "top_k": top_k,
#    1014             "top_p": top_p,
#    1015         },
#    1016         message_create_params.MessageCreateParamsStreaming
#    1017         if stream
#    1018         else message_create_params.MessageCreateParamsNonStreaming,
#    1019     ),
#    1020     options=make_request_options(
#    1021         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1022     ),
#    1023     cast_to=Message,
#    1024     stream=stream or False,
#    1025     stream_cls=Stream[RawMessageStreamEvent],
#    1026 )
#
# File ~/Desktop/langchain-basics/.venv/lib/python3.13/site-packages/anthropic/_base_client.py:1324, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1310 def post(
#    1311     self,
#    1312     path: str,
#    (...)   1319     stream_cls: type[_StreamT] | None = None,
#    1320 ) -> ResponseT | _StreamT:
#    1321     opts = FinalRequestOptions.construct(
#    1322         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1323     )
# -> 1324     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Desktop/langchain-basics/.venv/lib/python3.13/site-packages/anthropic/_base_client.py:1033, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1030 options = self._prepare_options(options)
#    1032 remaining_retries = max_retries - retries_taken
# -> 1033 request = self._build_request(options, retries_taken=retries_taken)
#    1034 self._prepare_request(request)
#    1036 kwargs: HttpxSendArgs = {}
#
# File ~/Desktop/langchain-basics/.venv/lib/python3.13/site-packages/anthropic/_base_client.py:506, in BaseClient._build_request(self, options, retries_taken)
#     503     else:
#     504         raise RuntimeError(f"Unexpected JSON data type, {type(json_data)}, cannot merge with `extra_body`")
# --> 506 headers = self._build_headers(options, retries_taken=retries_taken)
#     507 params = _merge_mappings(self.default_query, options.params)
#     508 content_type = headers.get("Content-Type")
#
# File ~/Desktop/langchain-basics/.venv/lib/python3.13/site-packages/anthropic/_base_client.py:447, in BaseClient._build_headers(self, options, retries_taken)
#     437 custom_headers = options.headers or {}
#     438 headers_dict = _merge_mappings(
#     439     {
#     440         "x-stainless-timeout": str(options.timeout.read)
#    (...)    445     custom_headers,
#     446 )
# --> 447 self._validate_headers(headers_dict, custom_headers)
#     449 # headers are case-insensitive while dictionaries are not.
#     450 headers = httpx.Headers(headers_dict)
#
# File ~/Desktop/langchain-basics/.venv/lib/python3.13/site-packages/anthropic/_client.py:196, in Anthropic._validate_headers(self, headers, custom_headers)
#     193 if isinstance(custom_headers.get("Authorization"), Omit):
#     194     return
# --> 196 raise TypeError(
#     197     '"Could not resolve authentication method. Expected either api_key or auth_token to be set. Or for one of the `X-Api-Key` or `Authorization` headers to be explicitly omitted"'
#     198 )
#
# TypeError: "Could not resolve authentication method. Expected either api_key or auth_token to be set. Or for one of the `X-Api-Key` or `Authorization` headers to be explicitly omitted"
